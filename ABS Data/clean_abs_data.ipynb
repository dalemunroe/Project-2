# %%
# Dependencies and Setup
import pandas as pd
import os

# %%
# Load csv with ABS data for median income
median_income = pd.read_csv('Resources/G02_median_incomes.csv')
median_income.head()
# Out:
#   POA_CODE_2021  Median_age_persons  Median_mortgage_repay_monthly  \
# 0       POA6182                   0                              0
# 1       POA6067                  33                              0
# 2       POA6770                  29                           1800
# 3       POA6718                  34                           1500
# 4       POA6765                  31                           1625
#
#    Median_tot_prsnl_inc_weekly  Median_rent_weekly  Median_tot_fam_inc_weekly  \
# 0                            0                   0                          0
# 1                          341                 150                        850
# 2                          367                  90                        794
# 3                          368                 150                       1006
# 4                          386                 100                        863
#
#    Average_num_psns_per_bedroom  Median_tot_hhd_inc_weekly  \
# ...

# %%
# Review columns for relevance
list(median_income.columns)
# Out:
# ['POA_CODE_2021',
#  'Median_age_persons',
#  'Median_mortgage_repay_monthly',
#  'Median_tot_prsnl_inc_weekly',
#  'Median_rent_weekly',
#  'Median_tot_fam_inc_weekly',
#  'Average_num_psns_per_bedroom',
#  'Median_tot_hhd_inc_weekly',
#  'Average_household_size']

# %%
# Remove superflus columns for median income
median_income = median_income[['POA_CODE_2021',
 'Median_age_persons',
 'Median_tot_prsnl_inc_weekly',
 'Median_tot_fam_inc_weekly',
 'Median_tot_hhd_inc_weekly']]
median_income.head()
# Out:
#   POA_CODE_2021  Median_age_persons  Median_tot_prsnl_inc_weekly  \
# 0       POA6182                   0                            0
# 1       POA6067                  33                          341
# 2       POA6770                  29                          367
# 3       POA6718                  34                          368
# 4       POA6765                  31                          386
#
#    Median_tot_fam_inc_weekly  Median_tot_hhd_inc_weekly
# 0                          0                          0
# 1                        850                        849
# 2                        794                       1066
# 3                       1006                       1074
# 4                        863                       1226

# %%
# Load csv with ABS data for income by hourshold composition
household_income = pd.read_csv('Resources/G33_household_income.csv')
household_income.head()
# Out:
#   POA_CODE_2021  Neg_Nil_inc_fam_households  Neg_Nil_inc_Non_fam_househlds  \
# 0       POA6000                          47                            129
# 1       POA6003                           7                             32
# 2       POA6004                          47                            116
# 3       POA6005                          16                             44
# 4       POA6006                          21                             42
#
#    Negative_Nil_income_Tot  HI_1_149_Family_households  \
# 0                      181                           6
# 1                       37                           0
# 2                      161                          10
# 3                       66                           4
# 4                       60                           3
#
#    HI_1_149_Non_family_hseholds  HI_1_149_Tot  HI_150_299_Family_households  \
# 0                            29            34                             7
# ...

# %%
# Review columns for relevance
list(household_income.columns)
# Out:
# ['POA_CODE_2021',
#  'Neg_Nil_inc_fam_households',
#  'Neg_Nil_inc_Non_fam_househlds',
#  'Negative_Nil_income_Tot',
#  'HI_1_149_Family_households',
#  'HI_1_149_Non_family_hseholds',
#  'HI_1_149_Tot',
#  'HI_150_299_Family_households',
#  'HI_150_299_Non_fam_househlds',
#  'HI_150_299_Tot',
#  'HI_300_399_Family_households',
#  'HI_300_399_Non_fam_househlds',
#  'HI_300_399_Tot',
#  'HI_400_499_Family_households',
#  'HI_400_499_Non_fam_househlds',
#  'HI_400_499_Tot',
#  'HI_500_649_Family_households',
#  'HI_500_649_Non_fam_househlds',
#  'HI_500_649_Tot',
#  'HI_650_799_Family_households',
#  'HI_650_799_Non_fam_househlds',
#  'HI_650_799_Tot',
#  'HI_800_999_Fam_households',
#  'HI_800_999_Non_fam_hsehlds',
#  'HI_800_999_Tot',
#  'HI_1000_1249_Fam_households',
#  'HI_1000_1249_Non_fam_hsehlds',
#  'HI_1000_1249_Tot',
#  'HI_1250_1499_Fam_households',
#  'HI_1250_1499_Non_fam_hsehlds',
#  'HI_1250_1499_Tot',
#  'HI_1500_1749_Fam_households',
#  'HI_1500_1749_Non_fam_hsehlds',
# ...

# %%
# Remove superflus columns for household income
household_income = household_income[['POA_CODE_2021',
 'Neg_Nil_inc_fam_households',
 'Neg_Nil_inc_Non_fam_househlds',
 'HI_1_149_Family_households',
 'HI_1_149_Non_family_hseholds',
 'HI_150_299_Family_households',
 'HI_150_299_Non_fam_househlds',
 'HI_300_399_Family_households',
 'HI_300_399_Non_fam_househlds',
 'HI_400_499_Family_households',
 'HI_400_499_Non_fam_househlds',
 'HI_500_649_Family_households',
 'HI_500_649_Non_fam_househlds',
 'HI_650_799_Family_households',
 'HI_650_799_Non_fam_househlds',
 'HI_800_999_Fam_households',
 'HI_800_999_Non_fam_hsehlds',
 'HI_1000_1249_Fam_households',
 'HI_1000_1249_Non_fam_hsehlds',
 'HI_1250_1499_Fam_households',
 'HI_1250_1499_Non_fam_hsehlds',
 'HI_1500_1749_Fam_households',
 'HI_1500_1749_Non_fam_hsehlds',
 'HI_1750_1999_Fam_households',
 'HI_1750_1999_Non_fam_hsehlds',
 'HI_2000_2499_Fam_households',
 'HI_2000_2499_Non_fam_hsehlds',
 'HI_2500_2999_Fam_households',
 'HI_2500_2999_Non_fam_hsehlds',
 'HI_3000_3499_Fam_households',
 'HI_3000_3499_Non_fam_hsehlds',
 'HI_3500_3999_Fam_households',
 'HI_3500_3999_Non_fam_hsehlds',
 'HI_4000_more_Fam_households',
 'HI_4000_more_Non_fam_hsehlds',
 'Part_inc_stated_Fam_household',
 'Part_inc_std_Non_fam_hhds',
 'All_incomes_ns_Famly_househld',
 'All_inc_ns_Non_famly_househld']]
household_income.head()
# Out:
#   POA_CODE_2021  Neg_Nil_inc_fam_households  Neg_Nil_inc_Non_fam_househlds  \
# 0       POA6000                          47                            129
# 1       POA6003                           7                             32
# 2       POA6004                          47                            116
# 3       POA6005                          16                             44
# 4       POA6006                          21                             42
#
#    HI_1_149_Family_households  HI_1_149_Non_family_hseholds  \
# 0                           6                            29
# 1                           0                             5
# 2                          10                            20
# 3                           4                            15
# 4                           3                            17
#
#    HI_150_299_Family_households  HI_150_299_Non_fam_househlds  \
# 0                             7                            63
# ...

# %%
# Load csv with ABS data for individual income
individual_incomeA = pd.read_csv('Resources/2021Census_G17A_WA_POA.csv')
individual_incomeB = pd.read_csv('Resources/2021Census_G17B_WA_POA.csv')
individual_incomeC = pd.read_csv('Resources/2021Census_G17C_WA_POA.csv')
# Merge the three individual income CSVs

individual_income = pd.concat([individual_incomeA,individual_incomeB,individual_incomeC],axis=1)
individual_income.head()
# Out:
#   POA_CODE_2021  M_Neg_Nil_income_15_19_yrs  M_Neg_Nil_income_20_24_yrs  \
# 0       POA6000                          54                         106
# 1       POA6003                          11                          11
# 2       POA6004                          41                          53
# 3       POA6005                          14                          18
# 4       POA6006                          89                          16
#
#    M_Neg_Nil_income_25_34_yrs  M_Neg_Nil_income_35_44_yrs  \
# 0                          95                          39
# 1                          11                           3
# 2                          57                          35
# 3                          27                          23
# 4                          15                          21
#
#    M_Neg_Nil_income_45_54_yrs  M_Neg_Nil_income_55_64_yrs  \
# 0                          27                          36
# 1                           0                           4
# ...

# %%
# Review columns for relevance
list(individual_income.columns)
# Out:
# ['POA_CODE_2021',
#  'M_Neg_Nil_income_15_19_yrs',
#  'M_Neg_Nil_income_20_24_yrs',
#  'M_Neg_Nil_income_25_34_yrs',
#  'M_Neg_Nil_income_35_44_yrs',
#  'M_Neg_Nil_income_45_54_yrs',
#  'M_Neg_Nil_income_55_64_yrs',
#  'M_Neg_Nil_income_65_74_yrs',
#  'M_Neg_Nil_income_75_84_yrs',
#  'M_Negtve_Nil_incme_85_yrs_ovr',
#  'M_Neg_Nil_income_Tot',
#  'M_1_149_15_19_yrs',
#  'M_1_149_20_24_yrs',
#  'M_1_149_25_34_yrs',
#  'M_1_149_35_44_yrs',
#  'M_1_149_45_54_yrs',
#  'M_1_149_55_64_yrs',
#  'M_1_149_65_74_yrs',
#  'M_1_149_75_84_yrs',
#  'M_1_149_85ov',
#  'M_1_149_Tot',
#  'M_150_299_15_19_yrs',
#  'M_150_299_20_24_yrs',
#  'M_150_299_25_34_yrs',
#  'M_150_299_35_44_yrs',
#  'M_150_299_45_54_yrs',
#  'M_150_299_55_64_yrs',
#  'M_150_299_65_74_yrs',
#  'M_150_299_75_84_yrs',
#  'M_150_299_85ov',
#  'M_150_299_Tot',
#  'M_300_399_15_19_yrs',
#  'M_300_399_20_24_yrs',
#  'M_300_399_25_34_yrs',
#  'M_300_399_35_44_yrs',
#  'M_300_399_45_54_yrs',
#  'M_300_399_55_64_yrs',
# ...

# %%
# Remove columns to remove gender split & totals
individual_income = individual_income[['POA_CODE_2021',
 'P_Neg_Nil_income_15_19_yrs',
 'P_Neg_Nil_income_20_24_yrs',
 'P_Neg_Nil_income_25_34_yrs',
 'P_Neg_Nil_income_35_44_yrs',
 'P_Neg_Nil_income_45_54_yrs',
 'P_Neg_Nil_income_55_64_yrs',
 'P_Neg_Nil_income_65_74_yrs',
 'P_Neg_Nil_income_75_84_yrs',
 'P_Negtve_Nil_incme_85_yrs_ovr',
 'P_1_149_15_19_yrs',
 'P_1_149_20_24_yrs',
 'P_1_149_25_34_yrs',
 'P_1_149_35_44_yrs',
 'P_1_149_45_54_yrs',
 'P_1_149_55_64_yrs',
 'P_1_149_65_74_yrs',
 'P_1_149_75_84_yrs',
 'P_1_149_85ov',
 'P_150_299_15_19_yrs',
 'P_150_299_20_24_yrs',
 'P_150_299_25_34_yrs',
 'P_150_299_35_44_yrs',
 'P_150_299_45_54_yrs',
 'P_150_299_55_64_yrs',
 'P_150_299_65_74_yrs',
 'P_150_299_75_84_yrs',
 'P_150_299_85ov',
 'P_300_399_15_19_yrs',
 'P_300_399_20_24_yrs',
 'P_300_399_25_34_yrs',
 'P_300_399_35_44_yrs',
 'P_300_399_45_54_yrs',
 'P_300_399_55_64_yrs',
 'P_300_399_65_74_yrs',
 'P_300_399_75_84_yrs',
 'P_300_399_85ov',
 'P_400_499_15_19_yrs',
 'P_400_499_20_24_yrs',
 'P_400_499_25_34_yrs',
 'P_400_499_35_44_yrs',
 'P_400_499_45_54_yrs',
 'P_400_499_55_64_yrs',
 'P_400_499_65_74_yrs',
 'P_400_499_75_84_yrs',
 'P_400_499_85ov',
 'P_400_499_Tot',
 'P_500_649_15_19_yrs',
 'P_500_649_20_24_yrs',
 'P_500_649_25_34_yrs',
 'P_500_649_35_44_yrs',
 'P_500_649_45_54_yrs',
 'P_500_649_55_64_yrs',
 'P_500_649_65_74_yrs',
 'P_500_649_75_84_yrs',
 'P_500_649_85ov',
 'P_650_799_15_19_yrs',
 'P_650_799_20_24_yrs',
 'P_650_799_25_34_yrs',
 'P_650_799_35_44_yrs',
 'P_650_799_45_54_yrs',
 'P_650_799_55_64_yrs',
 'P_650_799_65_74_yrs',
 'P_650_799_75_84_yrs',
 'P_650_799_85ov',
 'P_800_999_15_19_yrs',
 'P_800_999_20_24_yrs',
 'P_800_999_25_34_yrs',
 'P_800_999_35_44_yrs',
 'P_800_999_45_54_yrs',
 'P_800_999_55_64_yrs',
 'P_800_999_65_74_yrs',
 'P_800_999_75_84_yrs',
 'P_800_999_85ov',
 'P_1000_1249_15_19_yrs',
 'P_1000_1249_20_24_yrs',
 'P_1000_1249_25_34_yrs',
 'P_1000_1249_35_44_yrs',
 'P_1000_1249_45_54_yrs',
 'P_1000_1249_55_64_yrs',
 'P_1000_1249_65_74_yrs',
 'P_1000_1249_75_84_yrs',
 'P_1000_1249_85ov',
 'P_1250_1499_15_19_yrs',
 'P_1250_1499_20_24_yrs',
 'P_1250_1499_25_34_yrs',
 'P_1250_1499_35_44_yrs',
 'P_1250_1499_45_54_yrs',
 'P_1250_1499_55_64_yrs',
 'P_1250_1499_65_74_yrs',
 'P_1250_1499_75_84_yrs',
 'P_1250_1499_85ov',
 'P_1500_1749_15_19_yrs',
 'P_1500_1749_20_24_yrs',
 'P_1500_1749_25_34_yrs',
 'P_1500_1749_35_44_yrs',
 'P_1500_1749_45_54_yrs',
 'P_1500_1749_55_64_yrs',
 'P_1500_1749_65_74_yrs',
 'P_1500_1749_75_84_yrs',
 'P_1500_1749_85ov',
 'P_1750_1999_15_19_yrs',
 'P_1750_1999_20_24_yrs',
 'P_1750_1999_25_34_yrs',
 'P_1750_1999_35_44_yrs',
 'P_1750_1999_45_54_yrs',
 'P_1750_1999_55_64_yrs',
 'P_1750_1999_65_74_yrs',
 'P_1750_1999_75_84_yrs',
 'P_1750_1999_85ov',
 'P_2000_2999_15_19_yrs',
 'P_2000_2999_20_24_yrs',
 'P_2000_2999_25_34_yrs',
 'P_2000_2999_35_44_yrs',
 'P_2000_2999_45_54_yrs',
 'P_2000_2999_55_64_yrs',
 'P_2000_2999_65_74_yrs',
 'P_2000_2999_75_84_yrs',
 'P_2000_2999_85ov',
 'P_3000_3499_15_19_yrs',
 'P_3000_3499_20_24_yrs',
 'P_3000_3499_25_34_yrs',
 'P_3000_3499_35_44_yrs',
 'P_3000_3499_45_54_yrs',
 'P_3000_3499_55_64_yrs',
 'P_3000_3499_65_74_yrs',
 'P_3000_3499_75_84_yrs',
 'P_3000_3499_85ov',
 'P_3500_more_15_19_yrs',
 'P_3500_more_20_24_yrs',
 'P_3500_more_25_34_yrs',
 'P_3500_more_35_44_yrs',
 'P_3500_more_45_54_yrs',
 'P_3500_more_55_64_yrs',
 'P_3500_more_65_74_yrs',
 'P_3500_more_75_84_yrs',
 'P_3500_more_85ov',
 'P_PI_NS_15_19_yrs',
 'P_PI_NS_ns_20_24_yrs',
 'P_PI_NS_ns_25_34_yrs',
 'P_PI_NS_ns_35_44_yrs',
 'P_PI_NS_ns_45_54_yrs',
 'P_PI_NS_ns_55_64_yrs',
 'P_PI_NS_ns_65_74_yrs',
 'P_PI_NS_ns_75_84_yrs',
 'P_PI_NS_ns_85_yrs_ovr']]
individual_income.head()
# Out:
#   POA_CODE_2021 POA_CODE_2021 POA_CODE_2021  P_Neg_Nil_income_15_19_yrs  \
# 0       POA6000       POA6000       POA6000                          95
# 1       POA6003       POA6003       POA6003                          27
# 2       POA6004       POA6004       POA6004                          83
# 3       POA6005       POA6005       POA6005                          30
# 4       POA6006       POA6006       POA6006                         156
#
#    P_Neg_Nil_income_20_24_yrs  P_Neg_Nil_income_25_34_yrs  \
# 0                         217                         274
# 1                          26                          43
# 2                         112                         228
# 3                          30                          81
# 4                          36                          45
#
#    P_Neg_Nil_income_35_44_yrs  P_Neg_Nil_income_45_54_yrs  \
# 0                         149                          74
# 1                          20                          19
# ...
